# %% [markdown]
# VAE, AE, normal sampling, SDR

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim import Adam
from torch.optim.lr_scheduler import ReduceLROnPlateau

from sklearn.preprocessing import StandardScaler
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern, WhiteKernel
from scipy.stats import norm
from scipy.stats import qmc

import matplotlib.pyplot as plt

###############################################################################
#                           TestFunction Class                                #
###############################################################################

class TestFunction:
    def __init__(self, func_type, n_x, track_x=False, x_shift=None, bounds=None):
        self.f_list = []
        self.x_list = []
        self.best_f = []

        self.func_type = func_type
        self.n_x       = n_x
        self.track_x   = track_x

        if x_shift is not None:
            self.x_shift = x_shift
        else:
            self.x_shift = np.zeros((n_x, 1))
        if bounds is not None:
            self.lb = bounds[:, 0]
            self.ub = bounds[:, 1]
        else:
            self.lb = np.zeros(n_x)
            self.ub = np.ones(n_x)
        self.dim      = n_x
        self.int_var  = np.array([], dtype=int)
        self.cont_var = np.arange(0, n_x)

    def eval(self, x):
        x_arr = np.array(x).reshape((self.n_x, 1)) + self.x_shift

        if self.func_type == 'Rosenbrock_f':
            val = ((1.0 - x_arr)**2).sum() + 100.0 * ((x_arr[1:] - x_arr[:-1]**2)**2).sum()

        elif self.func_type == 'Levy_f':
            w = 1.0 + (x_arr - 1.0) / 4.0
            term1 = np.sin(np.pi * w[0])**2
            term2 = ((w[:-1] - 1.0)**2 * (1.0 + 10.0 * np.sin(np.pi * w[:-1] + 1.0)**2)).sum()
            term3 = (w[-1] - 1.0)**2 * (1.0 + np.sin(2.0 * np.pi * w[-1])**2)
            val = float(term1 + term2 + term3)

        elif self.func_type == 'Rastrigin_f':
            val = 10.0 * self.n_x + (x_arr**2 - 10.0 * np.cos(2.0 * np.pi * x_arr)).sum()
            val = float(val)

        elif self.func_type == 'Ackley_f':
            a, b, c = 20.0, 0.2, 2.0 * np.pi
            norm_sq = (x_arr**2).sum()
            term1 = -a * np.exp(-b * np.sqrt(norm_sq / self.n_x))
            term2 = -np.exp(np.cos(c * x_arr).sum() / self.n_x)
            val = float(term1 + term2 + a + np.e)

        elif self.func_type == '1_norm':
            val = float(np.abs(x_arr).sum())
        else:
            raise ValueError(f"Unsupported function type: {self.func_type}")

        self.f_list.append(val)
        if self.track_x:
            self.x_list.append(x_arr.copy())
        return val

###############################################################################
#                         0) Repro and device                                 #
###############################################################################

SEED = 43
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

###############################################################################
#                         1) Choose function and sample                       #
###############################################################################

dim       = 20
func_name = "Ackley_f"
bounds    = np.array([[-5.0, 5.0]] * dim)

t_func = TestFunction(
    func_type = func_name,
    n_x       = dim,
    track_x   = False,
    x_shift   = None,
    bounds    = bounds,
)

N  = 10000
lb = t_func.lb
ub = t_func.ub

U = np.random.rand(N, dim)
X = lb + U * (ub - lb)
X = X.astype(np.float32)

###############################################################################
#                         2) AE and VAE model                                 #
###############################################################################

LATENT_DIM = 5

class VAE(nn.Module):
    def __init__(self, input_dim=20, latent_dim=LATENT_DIM, mean_decoder=False):
        super().__init__()
        self.enc = nn.Sequential(
            nn.Linear(input_dim, 128), nn.SiLU(),
            nn.Linear(128, 64), nn.SiLU(),
            nn.Linear(64, 32), nn.SiLU(),
        )
        self.mu     = nn.Linear(32, latent_dim)
        self.logvar = nn.Linear(32, latent_dim)

        self.dec = nn.Sequential(
            nn.Linear(latent_dim, 32), nn.SiLU(),
            nn.Linear(32, 64), nn.SiLU(),
            nn.Linear(64, 128), nn.SiLU(),
            nn.Linear(128, input_dim),
        )

        self.mean_decoder = mean_decoder

    def reparam(self, mu, lv):
        std = torch.exp(0.5 * lv)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        h  = self.enc(x)
        mu = self.mu(h)
        lv = self.logvar(h)

        if self.mean_decoder:
            z = mu
        else:
            z = self.reparam(mu, lv)

        xhat = self.dec(z)
        return xhat, mu, lv, z

    @torch.no_grad()
    def encode_mu(self, x):
        h = self.enc(x)
        return self.mu(h)

    @torch.no_grad()
    def decode(self, z):
        return self.dec(z)

###############################################################################
#                 3) Shared trainer for AE and VAE                            #
###############################################################################

def train_autoencoder(
    X_full,
    latent_dim=LATENT_DIM,
    lr=0.002071334578703477,
    batch_size=128,
    max_epochs=800,
    patience=100,
    seed=42,
    kind="vae",               # "ae" or "vae"
    beta_start=0.0,
    beta_inc=0.01,
    beta_max=1.0,
    beta_freeze_epochs=20,
    log_every=20,
):
    assert kind in ["ae", "vae"]

    torch.manual_seed(seed)
    np.random.seed(seed)

    X_full = np.asarray(X_full, dtype=np.float32)
    N, D   = X_full.shape

    idx = np.random.permutation(N)
    split = int(0.8 * N)
    tr_idx, va_idx = idx[:split], idx[split:]

    Xtr_raw, Xva_raw = X_full[tr_idx], X_full[va_idx]

    mu  = Xtr_raw.mean(axis=0, keepdims=True).astype(np.float32)
    std = (Xtr_raw.std(axis=0, keepdims=True) + 1e-8).astype(np.float32)

    Xtr = (Xtr_raw - mu) / std
    Xva = (Xva_raw - mu) / std

    Xtr = np.ascontiguousarray(Xtr, dtype=np.float32)
    Xva = np.ascontiguousarray(Xva, dtype=np.float32)

    train_loader = DataLoader(
        TensorDataset(torch.from_numpy(Xtr), torch.from_numpy(Xtr)),
        batch_size=batch_size,
        shuffle=True,
        drop_last=False,
    )
    val_loader = DataLoader(
        TensorDataset(torch.from_numpy(Xva), torch.from_numpy(Xva)),
        batch_size=256,
        shuffle=False,
        drop_last=False,
    )

    use_mean_decoder = (kind == "ae")
    model = VAE(input_dim=D, latent_dim=latent_dim, mean_decoder=use_mean_decoder).to(device)

    opt   = Adam(model.parameters(), lr=lr)
    sched = ReduceLROnPlateau(opt, mode="min", factor=0.5, patience=20, min_lr=1e-6)
    mse   = nn.MSELoss(reduction="mean")

    train_hist, val_hist, beta_hist, kl_hist = [], [], [], []
    best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
    best_val_recon = np.inf
    no_imp = 0

    beta = beta_start

    for epoch in range(1, max_epochs + 1):
        if kind == "ae":
            beta_eff = 0.0
        else:
            if epoch <= beta_freeze_epochs:
                beta_eff = 0.0
            else:
                beta = min(beta + beta_inc, beta_max)
                beta_eff = beta

        model.train()
        tr_sum = 0.0
        kl_sum = 0.0
        n_tr = 0
        for xb, _ in train_loader:
            xb = xb.to(device)
            opt.zero_grad()
            xhat, mu_t, lv_t, _ = model(xb)
            recon = mse(xhat, xb)

            if kind == "vae" and beta_eff > 0.0:
                kl = -0.5 * torch.mean(torch.sum(1 + lv_t - mu_t.pow(2) - lv_t.exp(), dim=1))
            else:
                kl = torch.tensor(0.0, device=xb.device)

            loss = recon + beta_eff * kl
            loss.backward()
            opt.step()

            tr_sum += loss.item() * xb.size(0)
            kl_sum += kl.item() * xb.size(0)
            n_tr   += xb.size(0)

        tr_loss = tr_sum / n_tr
        kl_avg  = kl_sum / n_tr

        model.eval()
        rec_sum = 0.0
        n_va = 0
        with torch.no_grad():
            for xb, _ in val_loader:
                xb = xb.to(device)
                xhat, mu_t, lv_t, _ = model(xb)
                recon = mse(xhat, xb)
                rec_sum += recon.item() * xb.size(0)
                n_va   += xb.size(0)
        val_recon = rec_sum / n_va

        train_hist.append(tr_loss)
        val_hist.append(val_recon)
        beta_hist.append(beta_eff)
        kl_hist.append(kl_avg)

        sched.step(val_recon)

        if epoch == 1 or epoch % log_every == 0:
            print(
                f"[{kind.upper()}] Ep {epoch:4d}  beta {beta_eff:.3f}  "
                f"Train {tr_loss:.4f}  ValRecon {val_recon:.4f}  KL {kl_avg:.4f}"
            )

        if val_recon < best_val_recon - 1e-12:
            best_val_recon = val_recon
            best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            no_imp = 0
        else:
            no_imp += 1
            if no_imp >= patience:
                print(f"[{kind.upper()}] early stop at epoch {epoch}")
                break

    model.load_state_dict(best_state)
    model.to(device)
    model.eval()

    with torch.no_grad():
        Xt = torch.from_numpy(Xva).to(device)
        xhat = model(Xt)[0]
        final_mse = float(((xhat - Xt) ** 2).mean().cpu().item())

    print(f"[{kind.upper()}] best validation recon MSE: {final_mse:.6f}")

    history = {
        "train": np.array(train_hist),
        "val":   np.array(val_hist),
        "beta":  np.array(beta_hist),
        "kl":    np.array(kl_hist),
    }
    stats = {
        "mu": mu,
        "std": std,
        "val_mse_best": final_mse,
    }
    return model, history, stats

###############################################################################
#                         4) GP, EI and BO utilities with SDR                 #
###############################################################################

def make_gp(latent_dim):
    kernel = 1.0 * Matern(
        length_scale=np.ones(latent_dim),
        length_scale_bounds=(1e-2, 1e2),
        nu=2.5,
    )
    kernel += WhiteKernel(noise_level=1e-6, noise_level_bounds=(1e-8, 1e-2))

    return GaussianProcessRegressor(
        kernel=kernel,
        n_restarts_optimizer=5,
        alpha=1e-6,
        normalize_y=True,
    )


def expected_improvement(x, gp, best_y, xi):
    x = np.atleast_2d(x)
    mu, sigma = gp.predict(x, return_std=True)
    sigma = sigma + 1e-9
    imp = best_y - mu
    z = imp / sigma
    ei = imp * norm.cdf(z) + sigma * norm.pdf(z)
    return ei.ravel()


def propose_sobol_in_box(
    gp,
    best_y,
    lo,
    hi,
    latent_dim,
    xi,
    n_candidates=512,
    rng=None,
):
    lo = np.asarray(lo, dtype=np.float64)
    hi = np.asarray(hi, dtype=np.float64)

    sampler = qmc.Sobol(
        d=latent_dim,
        scramble=True,
        seed=None if rng is None else int(rng.randint(0, 10**9)),
    )
    U = sampler.random(n_candidates)
    Zc = qmc.scale(U, l_bounds=lo, u_bounds=hi)

    ei = expected_improvement(Zc, gp, best_y, xi)
    idx = np.argmax(ei)
    return Zc[idx]


def sdr_update_roi(
    best_z_history,
    roi_lo_prev,
    roi_hi_prev,
    global_lo,
    global_hi,
    r_prev,
    r_prev_prev,
    gamma0=0.7,
    gamma_p=1.0,
    eta=0.9,
    min_rel_width=0.02,
    r0=None,
):
    """
    One SDR update step, matching Appendix B.

    best_z_history: list of incumbents x^(0), ..., x^(k) (latent best points so far)
    roi_lo_prev, roi_hi_prev: RoI bounds at step k-1
    r_prev:   side lengths r^(k-1)
    r_prev_prev: side lengths r^(k-2)
    global_lo, global_hi: global box bounds
    r0: initial side lengths (for minimum width scaling)
    """
    global_lo = np.asarray(global_lo, dtype=np.float64)
    global_hi = np.asarray(global_hi, dtype=np.float64)

    roi_lo_prev = np.asarray(roi_lo_prev, dtype=np.float64)
    roi_hi_prev = np.asarray(roi_hi_prev, dtype=np.float64)
    r_prev      = np.asarray(r_prev, dtype=np.float64)

    if r0 is None:
        r0 = global_hi - global_lo
    r0 = np.asarray(r0, dtype=np.float64)

    # minimum absolute width as fraction of initial span
    r_min_abs = np.maximum(min_rel_width * r0, 1e-8)

    x_k  = np.asarray(best_z_history[-1], dtype=np.float64)

    # If we do not yet have three incumbents, keep width and just recenter
    if len(best_z_history) < 3 or r_prev_prev is None:
        r_new = np.maximum(r_prev, r_min_abs)
        center = x_k
    else:
        x_k1 = np.asarray(best_z_history[-2], dtype=np.float64)
        x_k2 = np.asarray(best_z_history[-3], dtype=np.float64)

        r_prev_prev = np.asarray(r_prev_prev, dtype=np.float64)
        r_prev      = np.maximum(r_prev,      r_min_abs)
        r_prev_prev = np.maximum(r_prev_prev, r_min_abs)

        # d^(k) uses r^(k-1), d^(k-1) uses r^(k-2)
        d_k  = 2.0 * (x_k  - x_k1) / r_prev
        d_k1 = 2.0 * (x_k1 - x_k2) / r_prev_prev

        c     = d_k * d_k1
        c_hat = np.sign(c) * np.sqrt(np.abs(c))

        gamma = 0.5 * (gamma_p * (1.0 + c_hat) + gamma0 * (1.0 - c_hat))
        lam   = eta + np.abs(d_k) * (gamma - eta)

        r_new = lam * r_prev
        r_new = np.maximum(r_new, r_min_abs)

        center = x_k

    roi_lo = np.maximum(center - 0.5 * r_new, global_lo)
    roi_hi = np.minimum(center + 0.5 * r_new, global_hi)

    # effective width after clipping
    r_eff = roi_hi - roi_lo
    r_eff = np.maximum(r_eff, r_min_abs)

    return roi_lo, roi_hi, r_eff, center


def optimise_latent_BO(
    latent_dim,
    objective,
    global_bounds,
    n_initial=40,
    n_iter=40,
    n_candidates=512,
    seed=42,
    gamma0=0.7,
    gamma_p=1.0,
    eta=0.9,
    min_rel_width=0.02,
    xi=1,              # SDR update period: update every xi BO steps
    t_min=None,        # absolute minimum side length (optional)
):
    rng = np.random.RandomState(seed)

    global_bounds = np.asarray(global_bounds, dtype=np.float64)
    lo_g = global_bounds[:, 0]
    hi_g = global_bounds[:, 1]

    r0 = hi_g - lo_g

    sampler = qmc.Sobol(d=latent_dim, scramble=True, seed=int(rng.randint(0, 10**9)))
    U0 = sampler.random(n_initial)
    Z = qmc.scale(U0, l_bounds=lo_g, u_bounds=hi_g)

    y = np.array([objective(z) for z in Z])

    best_idx = np.argmin(y)
    best_z   = Z[best_idx].copy()
    best_f   = y[best_idx]

    center0 = best_z.copy()
    roi_lo  = np.maximum(center0 - 0.5 * r0, lo_g)
    roi_hi  = np.minimum(center0 + 0.5 * r0, hi_g)
    r_curr  = roi_hi - roi_lo

    gp = make_gp(latent_dim)
    history        = [best_f]
    best_z_history = [best_z.copy()]
    r_history      = [r_curr.copy()]  # treat this as r^(0)

    for it in range(n_iter):
        gp.fit(Z, y)
        best_y = y.min()

        frac = it / max(1, n_iter - 1)
        xi_EI = 0.1 * (1.0 - frac) + 0.01 * frac

        z_new = propose_sobol_in_box(
            gp=gp,
            best_y=best_y,
            lo=roi_lo,
            hi=roi_hi,
            latent_dim=latent_dim,
            xi=xi_EI,
            n_candidates=n_candidates,
            rng=rng,
        )
        z_new = z_new + 1e-4 * rng.randn(latent_dim)

        y_new = objective(z_new)

        Z = np.vstack((Z, z_new))
        y = np.append(y, y_new)

        if y_new < best_f:
            best_f = y_new
            best_z = z_new

        best_z_history.append(best_z.copy())
        history.append(best_f)

        # SDR update every xi iterations, provided widths above t_min
        do_update = (xi is not None) and ((it + 1) % xi == 0)

        if do_update:
            r_prev      = r_history[-1]
            r_prev_prev = r_history[-2] if len(r_history) >= 2 else None

            if t_min is not None:
                # if all sides already below t_min, stop shrinking
                if np.all(r_prev <= t_min):
                    r_history.append(r_prev.copy())
                    continue

            roi_lo, roi_hi, r_curr, _ = sdr_update_roi(
                best_z_history=best_z_history,
                roi_lo_prev=roi_lo,
                roi_hi_prev=roi_hi,
                global_lo=lo_g,
                global_hi=hi_g,
                r_prev=r_prev,
                r_prev_prev=r_prev_prev,
                gamma0=gamma0,
                gamma_p=gamma_p,
                eta=eta,
                min_rel_width=min_rel_width,
                r0=r0,
            )
            r_history.append(r_curr.copy())

            print(
                f"[BO SDR] it {it+1:02d} | best {best_f:.4e} "
                f"| roi_width_min {r_curr.min():.3e} roi_width_max {r_curr.max():.3e}"
            )
        else:
            r_history.append(r_curr.copy())
            print(
                f"[BO SDR] it {it+1:02d} | best {best_f:.4e} "
                f"(no SDR update this step)"
            )

    return best_z, best_f, history, Z, y


###############################################################################
#                  5) Latent components for BO for a model                    #
###############################################################################

def build_latent_bo_components(model, mu_stats, std_stats, X, lb, ub, label="AE"):
    print(f"\nBuilding latent space for {label}")

    with torch.no_grad():
        Xn = ((X - mu_stats) / std_stats).astype(np.float32)
        Z_full = model.encode_mu(torch.from_numpy(Xn).to(device)).cpu().numpy()

    scZ = StandardScaler().fit(Z_full)
    Z_wh = scZ.transform(Z_full)

    latent_dim = Z_wh.shape[1]
    z_lo = np.quantile(Z_wh, 0.01, axis=0)
    z_hi = np.quantile(Z_wh, 0.99, axis=0)
    global_bounds = np.stack([z_lo, z_hi], axis=1)

    @torch.no_grad()
    def decode_from_whitened(z_wh_np):
        z = scZ.inverse_transform(np.asarray(z_wh_np, dtype=np.float32)[None, :])
        z_t = torch.from_numpy(z.astype(np.float32)).to(device)
        xhat_norm = model.decode(z_t).cpu().numpy()
        xhat = xhat_norm * std_stats + mu_stats
        xhat = np.clip(xhat[0], lb, ub)
        return xhat

    def latent_objective(z_wh):
        x_dec = decode_from_whitened(z_wh)
        return float(t_func.eval(x_dec))

    components = {
        "latent_dim": latent_dim,
        "global_bounds": global_bounds,
        "decode_fn": decode_from_whitened,
        "objective": latent_objective,
        "scaler": scZ,
    }
    return components

###############################################################################
#                         6) Train AE and VAE                                 #
###############################################################################

ae_model, ae_hist, ae_stats = train_autoencoder(
    X_full=X,
    latent_dim=LATENT_DIM,
    lr=1.5e-3,
    batch_size=128,
    max_epochs=400,
    patience=60,
    seed=SEED,
    kind="ae",
)

vae_model, vae_hist, vae_stats = train_autoencoder(
    X_full=X,
    latent_dim=LATENT_DIM,
    lr=1.5e-3,
    batch_size=128,
    max_epochs=600,
    patience=80,
    seed=SEED,
    kind="vae",
    beta_start=0.0,
    beta_inc=0.001,
    beta_max=0.05,
    beta_freeze_epochs=100,
)

print("\nAE best val MSE:", ae_stats["val_mse_best"])
print("VAE best val MSE:", vae_stats["val_mse_best"])

###############################################################################
#                         7) Plot AE and VAE losses                           #
###############################################################################

plt.figure(figsize=(6, 4))
plt.plot(ae_hist["train"], label="AE train")
plt.plot(ae_hist["val"], label="AE val")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("AE training and validation loss")
plt.legend()
plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(vae_hist["train"], label="VAE train")
plt.plot(vae_hist["val"], label="VAE val")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("VAE training and validation loss")
plt.legend()
plt.tight_layout()
plt.show()

###############################################################################
#                         8) Build latent spaces                              #
###############################################################################

ae_components = build_latent_bo_components(
    model=ae_model,
    mu_stats=ae_stats["mu"],
    std_stats=ae_stats["std"],
    X=X,
    lb=lb,
    ub=ub,
    label="AE",
)

vae_components = build_latent_bo_components(
    model=vae_model,
    mu_stats=vae_stats["mu"],
    std_stats=vae_stats["std"],
    X=X,
    lb=lb,
    ub=ub,
    label="VAE",
)

###############################################################################
#                         9) BO in AE latent space with SDR                   #
###############################################################################

best_z_ae, best_f_ae, hist_ae, Z_all_ae, y_all_ae = optimise_latent_BO(
    latent_dim=ae_components["latent_dim"],
    objective=ae_components["objective"],
    global_bounds=ae_components["global_bounds"],
    n_initial=40,
    n_iter=100,
    n_candidates=512,
    seed=SEED,
)

print("\n[AE latent BO SDR]")
print("Best latent z:", best_z_ae)
print("Best objective value:", best_f_ae)
best_x_ae = ae_components["decode_fn"](best_z_ae)
print("Decoded best x (first three dims):", best_x_ae[:3])

###############################################################################
#                         10) BO in VAE latent space with SDR                 #
###############################################################################

best_z_vae, best_f_vae, hist_vae, Z_all_vae, y_all_vae = optimise_latent_BO(
    latent_dim=vae_components["latent_dim"],
    objective=vae_components["objective"],
    global_bounds=vae_components["global_bounds"],
    n_initial=40,
    n_iter=100,
    n_candidates=512,
    seed=SEED,
)

print("\n[VAE latent BO SDR]")
print("Best latent z:", best_z_vae)
print("Best objective value:", best_f_vae)
best_x_vae = vae_components["decode_fn"](best_z_vae)
print("Decoded best x (first three dims):", best_x_vae[:3])

###############################################################################
#                         11) Compare BO traces                               #
###############################################################################

plt.figure(figsize=(6, 4))
plt.plot(hist_ae, label="AE latent BO SDR")
plt.plot(hist_vae, label="VAE latent BO SDR")
plt.xlabel("iteration")
plt.ylabel("best objective so far")
plt.title("BO in AE versus VAE latent space with SDR")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [AE] Ep    1  beta 0.000  Train 0.9284  ValRecon 0.8369  KL 0.0000
# [AE] Ep   20  beta 0.000  Train 0.6091  ValRecon 0.6768  KL 0.0000
# [AE] Ep   40  beta 0.000  Train 0.5592  ValRecon 0.6810  KL 0.0000
# [AE] Ep   60  beta 0.000  Train 0.5251  ValRecon 0.6965  KL 0.0000
# [AE] Ep   80  beta 0.000  Train 0.5078  ValRecon 0.7080  KL 0.0000
# [AE] early stop at epoch 87
# [AE] best validation recon MSE: 0.673042
# [VAE] Ep    1  beta 0.000  Train 0.9652  ValRecon 0.8834  KL 0.0000
# [VAE] Ep   20  beta 0.000  Train 0.6157  ValRecon 0.6766  KL 0.0000
# [VAE] Ep   40  beta 0.000  Train 0.5644  ValRecon 0.6761  KL 0.0000
# [VAE] Ep   60  beta 0.000  Train 0.5304  ValRecon 0.6898  KL 0.0000
# [VAE] Ep   80  beta 0.000  Train 0.5132  ValRecon 0.7019  KL 0.0000
# [VAE] Ep  100  beta 0.000  Train 0.5044  ValRecon 0.7083  KL 0.0000
# [VAE] early stop at epoch 107
# [VAE] best validation recon MSE: 0.672646
#
# AE best val MSE: 0.6730424165725708
# VAE best val MSE: 0.6726464629173279
# Building latent space for AE
#
# Building latent space for VAE
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\scipy\stats\_qmc.py:804: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# [BO SDR] it 01 | best 7.3411e+00 | roi_width_min 3.891e+00 roi_width_max 4.486e+00
# [BO SDR] it 02 | best 7.3411e+00 | roi_width_min 3.502e+00 roi_width_max 4.037e+00
# [BO SDR] it 03 | best 7.3411e+00 | roi_width_min 3.152e+00 roi_width_max 3.634e+00
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 04 | best 7.3061e+00 | roi_width_min 2.137e+00 roi_width_max 3.196e+00
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 05 | best 7.3061e+00 | roi_width_min 1.632e+00 roi_width_max 2.876e+00
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 06 | best 7.2087e+00 | roi_width_min 1.396e+00 roi_width_max 2.582e+00
# [BO SDR] it 07 | best 7.0978e+00 | roi_width_min 1.210e+00 roi_width_max 2.307e+00
# [BO SDR] it 08 | best 7.0978e+00 | roi_width_min 1.089e+00 roi_width_max 2.076e+00
# [BO SDR] it 09 | best 6.9879e+00 | roi_width_min 9.295e-01 roi_width_max 1.836e+00
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 10 | best 6.9879e+00 | roi_width_min 8.365e-01 roi_width_max 1.653e+00
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 11 | best 6.9879e+00 | roi_width_min 7.529e-01 roi_width_max 1.487e+00
# [BO SDR] it 12 | best 6.9879e+00 | roi_width_min 6.776e-01 roi_width_max 1.339e+00
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 13 | best 6.8806e+00 | roi_width_min 5.974e-01 roi_width_max 1.198e+00
# [BO SDR] it 14 | best 6.8806e+00 | roi_width_min 5.377e-01 roi_width_max 1.078e+00
# [BO SDR] it 15 | best 6.8806e+00 | roi_width_min 4.839e-01 roi_width_max 9.700e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 16 | best 6.8806e+00 | roi_width_min 4.355e-01 roi_width_max 8.730e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 17 | best 6.8806e+00 | roi_width_min 3.920e-01 roi_width_max 7.857e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 18 | best 6.8806e+00 | roi_width_min 3.528e-01 roi_width_max 7.071e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 19 | best 6.8806e+00 | roi_width_min 3.175e-01 roi_width_max 6.364e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 20 | best 6.8806e+00 | roi_width_min 2.857e-01 roi_width_max 5.728e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 21 | best 6.7257e+00 | roi_width_min 2.460e-01 roi_width_max 5.111e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 22 | best 6.7257e+00 | roi_width_min 2.214e-01 roi_width_max 4.600e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 23 | best 6.7257e+00 | roi_width_min 1.993e-01 roi_width_max 4.140e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 24 | best 6.7257e+00 | roi_width_min 1.793e-01 roi_width_max 3.726e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 25 | best 6.7257e+00 | roi_width_min 1.614e-01 roi_width_max 3.353e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 26 | best 6.7257e+00 | roi_width_min 1.453e-01 roi_width_max 3.018e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 27 | best 6.7257e+00 | roi_width_min 1.307e-01 roi_width_max 2.716e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 28 | best 6.7106e+00 | roi_width_min 1.112e-01 roi_width_max 2.382e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 29 | best 6.7106e+00 | roi_width_min 1.001e-01 roi_width_max 2.144e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 30 | best 6.7106e+00 | roi_width_min 9.842e-02 roi_width_max 1.930e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 31 | best 6.5666e+00 | roi_width_min 9.842e-02 roi_width_max 1.643e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 32 | best 6.5666e+00 | roi_width_min 9.842e-02 roi_width_max 1.479e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 33 | best 6.5666e+00 | roi_width_min 9.842e-02 roi_width_max 1.331e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 34 | best 6.5666e+00 | roi_width_min 9.842e-02 roi_width_max 1.198e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 35 | best 6.5666e+00 | roi_width_min 9.842e-02 roi_width_max 1.078e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 36 | best 6.5666e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 37 | best 6.5666e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 38 | best 6.5666e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 39 | best 6.5666e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 40 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 41 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 42 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 43 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 44 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 45 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 46 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 47 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 48 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 49 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 50 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 51 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 52 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 53 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 54 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 55 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 1 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified upper bound 0.01. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 56 | best 6.3424e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# [BO SDR] it 57 | best 6.2987e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# [BO SDR] it 58 | best 6.2964e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# [BO SDR] it 59 | best 6.2813e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# [BO SDR] it 60 | best 6.2813e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 61 | best 6.2813e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 62 | best 6.2649e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 63 | best 6.2649e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 64 | best 6.2454e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 65 | best 6.2454e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 66 | best 6.1457e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 67 | best 6.1457e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 68 | best 6.1457e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 69 | best 6.1457e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 70 | best 6.1457e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 71 | best 6.1457e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 72 | best 6.1118e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 73 | best 6.1118e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 74 | best 6.1118e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 75 | best 6.1118e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 76 | best 6.1118e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 77 | best 6.1118e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 78 | best 6.1100e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 79 | best 6.1100e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 80 | best 6.1100e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 81 | best 6.1100e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 82 | best 6.1100e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 83 | best 6.1042e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 84 | best 6.1042e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 85 | best 6.1042e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 86 | best 6.1042e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 87 | best 6.1042e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 88 | best 6.1042e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 89 | best 6.1041e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 90 | best 6.0980e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 91 | best 6.0980e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 92 | best 6.0980e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 93 | best 6.0980e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 94 | best 6.0980e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 95 | best 6.0980e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 96 | best 6.0980e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 97 | best 6.0980e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 98 | best 6.0980e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 99 | best 6.0980e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\scipy\stats\_qmc.py:804: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# [BO SDR] it 100 | best 6.0980e+00 | roi_width_min 9.842e-02 roi_width_max 1.013e-01
#
# [AE latent BO SDR]
# Best latent z: [ 0.41647126  0.38346049 -0.81133543  0.74654641 -0.67661236]
# Best objective value: 6.097973054756054
# Decoded best x (first three dims): [ 1.01312709  1.96431661 -0.27720866]
# ...
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 65 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 66 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 67 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 68 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 2 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 69 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 2 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 70 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 71 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 72 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 73 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 74 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 75 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 76 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 77 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# [BO SDR] it 78 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 79 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:452: ConvergenceWarning: The optimal value found for dimension 3 of parameter k1__k2__length_scale is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 80 | best 6.4394e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 81 | best 6.3668e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 82 | best 6.3578e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 83 | best 6.3578e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 84 | best 6.3578e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 85 | best 6.3578e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 86 | best 6.3578e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 87 | best 6.3578e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 88 | best 6.3578e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 89 | best 6.3578e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 90 | best 6.3549e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 91 | best 6.3539e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 92 | best 6.3539e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 93 | best 6.3539e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 94 | best 6.3539e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 95 | best 6.3539e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 96 | best 6.3539e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 97 | best 6.3539e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 98 | best 6.3539e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
# [BO SDR] it 99 | best 6.3539e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
# [BO SDR] it 100 | best 6.3539e+00 | roi_width_min 9.862e-02 roi_width_max 1.013e-01
#
# [VAE latent BO SDR]
# Best latent z: [-0.90828602  1.01523797 -0.02987243  0.63383704 -0.77103448]
# Best objective value: 6.3538769721302195
# Decoded best x (first three dims): [3.18162775 1.76777971 0.02993773]
# c:\Users\sg2222\OneDrive - Imperial College London\Documents\Python\Python1\my_venv\Lib\site-packages\sklearn\gaussian_process\kernels.py:442: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__noise_level is close to the specified lower bound 1e-08. Decreasing the bound and calling fit again may find a better value.
#   warnings.warn(
